# %%
from scipy.spatial import distance
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('globalcount_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24051 entries, 0 to 24050
# Data columns (total 92 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   row_id                                                   24051 non-null  int64
#  1   unique_id                                                24051 non-null  int64
#  2   survey_type                                              24051 non-null  object
#  3   iso3166                                                  24046 non-null  object
#  4   surveydate                                               24051 non-null  object
#  5   city_town                                                24049 non-null  object
#  6   city_town_tr                                             20503 non-null  object
#  7   country_of_residence                                     24050 non-null  object
# ...

# %%
distance.dice(df.iloc[:,34], df.iloc[:, 34])
# Out:
# 0.0

# %%
new_df = df.iloc[:, 34:46]

# %%
new_df.columns
# Out:
# Index(['issue_person_civil_rights_and_freedoms',
#        'issue_person_disability_rights',
#        'issue_person_economic_and_workers_rights',
#        'issue_person_education_and_youth_empowerment',
#        'issue_person_ending_violence_harassment_and_abuse',
#        'issue_person_environmental_justice',
#        'issue_person_immigrant_and_refugee_rights',
#        'issue_person_indigenous_andor_roma_rights',
#        'issue_person_LGBTQI+_rights', 'issue_person_racial_equity',
#        'issue_person_reproductive_freedom_and_bodily_autonomy',
#        'issue_person_sexual_reproductive_and_parental_health'],
#       dtype='object')

# %%
new_df.columns = ['Civil Rights & Freedoms', 'Disability Rights', 'Economic Rights', 'Education', 'Violence & Harassment', 'Environmental Justice', 'Immigrant & Refugee Rights', 'Indigenous Rights', 'LGBTQI+ Rights', 'Racial Equity', 'Reproductive Freedom & Bodily Autonomy', 'Reproductive & Parental Health']

# %%
cm = df.iloc[:, 34:46].corr(method = distance.dice)

# %%
cm = new_df.corr(method = distance.dice)

# %%
cm
# Out:
#                                         Civil Rights & Freedoms  \
# Civil Rights & Freedoms                                1.000000
# Disability Rights                                      0.890997
# Economic Rights                                        0.757551
# Education                                              0.740981
# Violence & Harassment                                  0.647577
# Environmental Justice                                  0.741981
# Immigrant & Refugee Rights                             0.947992
# Indigenous Rights                                      0.966384
# LGBTQI+ Rights                                         0.857295
# Racial Equity                                          0.843258
# Reproductive Freedom & Bodily Autonomy                 0.842773
# Reproductive & Parental Health                         0.877555
#
#                                         Disability Rights  Economic Rights  \
# ...

# %%
sns.heatmap(cm)
# Out:
# <AxesSubplot:>

# %%
1 - cm
# Out:
#                                         Civil Rights & Freedoms  \
# Civil Rights & Freedoms                                0.000000
# Disability Rights                                      0.109003
# Economic Rights                                        0.242449
# Education                                              0.259019
# Violence & Harassment                                  0.352423
# Environmental Justice                                  0.258019
# Immigrant & Refugee Rights                             0.052008
# Indigenous Rights                                      0.033616
# LGBTQI+ Rights                                         0.142705
# Racial Equity                                          0.156742
# Reproductive Freedom & Bodily Autonomy                 0.157227
# Reproductive & Parental Health                         0.122445
#
#                                         Disability Rights  Economic Rights  \
# ...

# %%
ax = sns.heatmap(
    cm, 
    vmin = 0, vmax = 1,
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
distance.dice([1, 1, 1], [1, 1, 1])
# Out:
# 0.0

# %%
distance.kulsinski([1, 1, 1, 1], [1, 1, 1, 1])
# Out:
# 0.0
